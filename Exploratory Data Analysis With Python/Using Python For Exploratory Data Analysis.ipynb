# %% [markdown]
# # Lab 2 (Part II)
# ## Using Python for Exploratory Data Analysis (EDA)
#
# The first part of Lab2 is to go through a demo for EDA of a relatively clean tabular data called *Auto MPG data*. This data set comes from the UCI Machine Learning Data Repository (http://archive.ics.uci.edu/ml/) and can be found at http://archive.ics.uci.edu/ml/datasets/Auto+MPG. We provide a slightly modified version of this data set as file `cars.csv`.
#
# To load this data set and pursue EDA, it is a good idea to use several popular Python packages, which come preloaded with the Anaconda software:
# - pandas (http://pandas.pydata.org/) -- a library for data science
# - numpy (http://www.numpy.org/) -- a library for data computations
# - matplotlib (http://matplotlib.org/) -- a library for data visualization
#
# The main feature of *pandas* is its `DataFrame` data structure that provides an intuitive way of handling tabular data. The main feature of *numpy* is its `array` data structure that represents matrices and allows us to perform matrix algebra operations. *matplotlib* allows visualizing data stored in `DataFrame` or `array` objects.
#
# As you will soon realize, each new Python library requires spending some time to learn about it. There are several nice tutorials that you can find on the web that get you started with the 3 libraries. A particularly great resource for learning about those libraries is your textbook *Python for Data Analysis*, so please take some time to browse its contents and try to run the code provided in it. When learning about the new libraries, you are best advised to jump in and immediatelly start tinkering with the code. The more time you spend using the library, the more you will uncover about all the great features and posibilities the library offers you.
#
# Let us start by loading the 3 libraries in a particular way that many data scientists prefer.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# the following line allows ipython to display plots
# %matplotlib inline

# %% [markdown]
# **Question 1**: What are we accomplishing with `as` reserved word?

# %% [markdown]
# **Answer 1**: We can give a library name an alias. An alias is usually shorter than the original name or something that is easy to remember for the person that is running the library.

# %% [markdown]
# `cars.csv` is in an easy-to-read comma separated format and the following *pandas* functionality makes it easy to read it into a `DataFrame` object.

# %%
# read this csv file, remember to put the full path to 
# the directory where you saved the data
df = pd.read_csv('cars.csv')  # df is DataFrame object
print (df.head())    # see the first 5 rows of the loaded table
# Out:
#                          Car   MPG  Cylinders  Displacement  Horsepower  \
# 0  Chevrolet Chevelle Malibu  18.0          8         307.0         130
# 1          Buick Skylark 320  15.0          8         350.0         165
# 2         Plymouth Satellite  18.0          8         318.0         150
# 3              AMC Rebel SST  16.0          8         304.0         150
# 4                Ford Torino  17.0          8         302.0         140
#
#    Weight  Acceleration  Model Origin
# 0    3504          12.0     70     US
# 1    3693          11.5     70     US
# 2    3436          11.0     70     US
# 3    3433          12.0     70     US
# 4    3449          10.5     70     US

# %% [markdown]
# **Question 2**: How can you display the first 10 rows using method `head`? What are the types of each of the columns in `df`?

# %% [markdown]
# **Answer 2**:
# To display the first 10 rows using head, we pass in the integer 10 as an argument into the head() method. Like df.head(10)
#
# Using dtypes attribute of a DataFrame object. We can see the different types for each column.
#
# For columns called "Car, Origin", we have object type or in other words, they are strings.
# For columns called "MPG, Displacement, Acceleration", we have floats.
# For columns called "Cylinders, Horsepower, Weight, Model", we have integers.

# %% [markdown]
# There are different ways of exploring and indexing the table. Here are some examples.

# %%
print (list(df.columns))

# print the first 5 rows, same outcome as df.head()
print (df[0:5])         

# print the first 10 rows for selected columns
print (df[['Car', 'MPG']][:10])  

# using Boolean condition, print only cars with MPG > 40
print (df[df['MPG'] > 40])   

# uses 'ix' indexing, selects rows and columns based on their location in the table
print (df.ix[[0,1,5],0:5])
# Out:
# ['Car', 'MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight', 'Acceleration', 'Model', 'Origin']
#                          Car   MPG  Cylinders  Displacement  Horsepower  \
# 0  Chevrolet Chevelle Malibu  18.0          8         307.0         130
# 1          Buick Skylark 320  15.0          8         350.0         165
# 2         Plymouth Satellite  18.0          8         318.0         150
# 3              AMC Rebel SST  16.0          8         304.0         150
# 4                Ford Torino  17.0          8         302.0         140
#
#    Weight  Acceleration  Model Origin
# 0    3504          12.0     70     US
# 1    3693          11.5     70     US
# 2    3436          11.0     70     US
# 3    3433          12.0     70     US
# 4    3449          10.5     70     US
#                          Car   MPG
# 0  Chevrolet Chevelle Malibu  18.0
# 1          Buick Skylark 320  15.0
# 2         Plymouth Satellite  18.0
# 3              AMC Rebel SST  16.0
# ...

# %% [markdown]
# **Question 3**: Show two ways of printing the last 5 rows of `df`. Print the names of the cars with 3 cilinders.

# %% [markdown]
# **Answer 3**

# %%
# first way
print(df.tail(5))
# Out:
#                    Car   MPG  Cylinders  Displacement  Horsepower  Weight  \
# 401    Ford Mustang GL  27.0          4         140.0          86    2790
# 402  Volkswagen Pickup  44.0          4          97.0          52    2130
# 403      Dodge Rampage  32.0          4         135.0          84    2295
# 404        Ford Ranger  28.0          4         120.0          79    2625
# 405         Chevy S-10  31.0          4         119.0          82    2720
#
#      Acceleration  Model  Origin
# 401          15.6     82      US
# 402          24.6     82  Europe
# 403          11.6     82      US
# 404          18.6     82      US
# 405          19.4     82      US

# %%
# second way
# using -5: just like how we would on a regular Python array
print(df.iloc[-5:])
# Out:
#                    Car   MPG  Cylinders  Displacement  Horsepower  Weight  \
# 401    Ford Mustang GL  27.0          4         140.0          86    2790
# 402  Volkswagen Pickup  44.0          4          97.0          52    2130
# 403      Dodge Rampage  32.0          4         135.0          84    2295
# 404        Ford Ranger  28.0          4         120.0          79    2625
# 405         Chevy S-10  31.0          4         119.0          82    2720
#
#      Acceleration  Model  Origin
# 401          15.6     82      US
# 402          24.6     82  Europe
# 403          11.6     82      US
# 404          18.6     82      US
# 405          19.4     82      US

# %% [markdown]
# Now, we are ready to start plotting the data.

# %%
# new modification from original notebook

# printing the names of cars with 3 cylinders
car_3_cylinders = df[df['Cylinders'] == 3]['Car'] 
car_list = list(car_3_cylinders)
print(car_list)
# Out:
# ['Mazda RX2 Coupe', 'Mazda RX3', 'Mazda RX-4', 'Mazda RX-7 GS']

# %%
plt.figure(figsize=(6,2))  # can control the size of the display
plt.xlabel("Horsepower")
plt.ylabel("Count")
plt.plot(df['Horsepower'])      # display 'Model' attribute

# %%
df['Horsepower'].describe()
# Out:
# count    406.000000
# mean     103.529557
# std       40.520659
# min        0.000000
# 25%       75.000000
# 50%       93.500000
# 75%      129.000000
# max      230.000000
# Name: Horsepower, dtype: float64

# %%
df.boxplot(column='Horsepower', by='Model');

# %% [markdown]
# **Question 4**: Plot *Horsepower* attribute, but only for the US cars.

# %% [markdown]
# **Answer 4**

# %%
# we will use boolean indexing

# check whether the value US exists in the Origin column 
print('US' in df['Origin'].unique())

plt.plot(df[df['Origin'] == 'US']['Horsepower'])
# Out:
# True

# %% [markdown]
# To plot the histogram of a selected attribute:

# %%
fig = plt.figure(figsize=(5,2))
plt.hist(df['MPG'], bins=20);   # ; suppresses Out
# plt.hist(df['Cylinders'], bins=20)

# %%
# new modification from original notebook

plt.hist(df['Cylinders'], bins=20)
# Out:
# (array([  4.,   0.,   0.,   0., 207.,   0.,   0.,   0.,   3.,   0.,   0.,
#           0.,  84.,   0.,   0.,   0.,   0.,   0.,   0., 108.]),
#  array([3.  , 3.25, 3.5 , 3.75, 4.  , 4.25, 4.5 , 4.75, 5.  , 5.25, 5.5 ,
#         5.75, 6.  , 6.25, 6.5 , 6.75, 7.  , 7.25, 7.5 , 7.75, 8.  ]),
#  <a list of 20 Patch objects>)

# %% [markdown]
# **Question 5**: What can we conclude by looking at the histogram? Explain in one-two sentences. Figure out what is your preferred number of bins for *MPG* and *Cylinders* and argue why.

# %% [markdown]
# From looking at the histogram, we can say that 15 MPG cars are the most popular.
#
# The distribution is mostly concentrated in the 10 - upper 30 MPG range.
#
# My preferred number for MPG is 40 or higher because the values are more varied. A larger number of bins would provide a more granular detail and allow us to see a more detailed distribution for the MPG attribute.
#
# My preferred number for Cylinders is 20 or less because the values are not that varied.
#
# Size Of a Bar/Box/Bin = Max - Min / # of Bins
#
# If number of bins too large then the size for each bin is small, then the possibility of having boxes or bins in which there is no data points for bins in that range might increase.

# %%
# new modification from original notebook
# trying out with a larger value for bins paramater
plt.hist(df['MPG'], bins=40)
# Out:
# (array([ 8.,  0.,  0.,  0.,  0.,  0.,  0.,  1.,  2.,  4.,  6., 20., 36.,
#         19., 11., 32., 19., 21., 23., 14., 19., 18., 19., 16., 21., 12.,
#         12., 16., 10., 11., 12.,  5.,  7.,  3.,  0.,  3.,  1.,  2.,  2.,
#          1.]),
#  array([ 0.   ,  1.165,  2.33 ,  3.495,  4.66 ,  5.825,  6.99 ,  8.155,
#          9.32 , 10.485, 11.65 , 12.815, 13.98 , 15.145, 16.31 , 17.475,
#         18.64 , 19.805, 20.97 , 22.135, 23.3  , 24.465, 25.63 , 26.795,
#         27.96 , 29.125, 30.29 , 31.455, 32.62 , 33.785, 34.95 , 36.115,
#         37.28 , 38.445, 39.61 , 40.775, 41.94 , 43.105, 44.27 , 45.435,
#         46.6  ]),
#  <a list of 40 Patch objects>)

# %%
# new modification from original notebook
plt.hist(df['Cylinders'], bins=5)
# Out:
# (array([  4., 207.,   3.,  84., 108.]),
#  array([3., 4., 5., 6., 7., 8.]),
#  <a list of 5 Patch objects>)

# %% [markdown]
# The following code provides statistics for number of cylinders.

# %%
t = pd.crosstab(index=df["Cylinders"],  # Make a crosstab
                     columns="count")     # Name the count column
t['percentage']= (t/t.sum())*100
print (t)
# Out:
# col_0      count  percentage
# Cylinders
# 3              4    0.985222
# 4            207   50.985222
# 5              3    0.738916
# 6             84   20.689655
# 8            108   26.600985

# %% [markdown]
# **Question 6**: Try to learn more about `crosstab` method (by doing Google search) and write a line of code that uses it in a different way on `df` data.

# %% [markdown]
# Source: https://pbpython.com/pandas-crosstab.html
#
# Cross tab allows us to count the frequency of objects that fall under 2 or more attributes.
#
# Basically, it allows us to group data in terms of attributes and then show us their frequency.
#
# For the example above, we want to see the frequency of cars based on their number of cylinders

# %% [markdown]
# Horizontal bar plot:

# %%
plt.figure(figsize=(5,2))
plt.barh(t.index,t["count"]);

# %% [markdown]
# **Question 7**: How about a horizontal bar plot? Can you learn how to control the width of bars and make a plot that has thinner bars?

# %% [markdown]
# We can control the "width" of the bar by setting the height attribute.
#
# Online documentation: https://matplotlib.org/api/_as_gen/matplotlib.pyplot.barh.html
#
# This can be a bit tricky when I first approached this problem because in the online documentation, there is an attribute called width, which is passed as the second argument but it does not control the geometric width that is asked of us in this question.
#
# The width that is mentioned in the online documentation is how stretched out do you want the horizontal bar to go.

# %%
# the bars are much thinner with the height property 
# set as a small value 
plt.barh(t.index,t["count"], height=.2)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# Pie chart:

# %%
plt.figure(figsize=(5,2))
plt.axis("equal")
plt.pie(t["count"],labels=t.index,startangle=90);

# %% [markdown]
# **Question 8**: Do you prefer bar or pie displayed chart and why?

# %% [markdown]
# **Answer 8:** In a pie chart, you are able to see the distribution of one component vis a vis the whole much better. You are able to see how much does one component make up the whole. It is good to compare one component to the whole.
#
# In a bar chart, you are able to see the shape of a distribution. You can see whether it is skewed toward one value of another. It is good to observe skewness.
#
# In the context of MPG in this problem, I find the vertical bar chart more insightful because MPG has a lot of varied values.
#
# If I put it in a pie chart, I would not be able to capture as much detail as I would like because for MPG values that are not as frequent like others, it will takes up a small part of the pie and therefore, it does not capture as much attention.
#
# Another reason is I want to see what kind of values for MPG in which most car are concentrated around rather than to compare whether one range of MPG values occupies more share than another range of MPG values.

# %% [markdown]
# The following is a boxplot of MPG values for each of the model years. Pay attention that matplotlib is not used here. Instead, we called a panda `boxplot` method

# %%
df.boxplot(column='MPG',by='Model');

# %% [markdown]
# **Question 9**: Discuss what can you learn from the displayed boxplot. Plot another boxplot using `df` data that you think is very useful and explain what can we learn from it?

# %% [markdown]
# **Answer 9**: From the above boxplot, I can gage the distribution in groups of 4 (0-25, 25-50, 50-75, 75-100) for each model year.

# %%
# new modification from original notebook
# plotting another box plot
df.boxplot(column="Horsepower", by="Origin")

# %% [markdown]
# Above is a boxplot of horsepower by each origin. I think it helps us to observe the distribution of horsepower to see which country has the most varied number of horsepower in terms of cars.

# %% [markdown]
# Scatterplot between MPG and Weight attributes:

# %%
plt.figure(figsize=(5,3))

# first arg is x and second arg is y
plt.xlabel("MPG")
plt.ylabel("Weight")
plt.scatter(df['MPG'],df['Weight']);

# %% [markdown]
# **Question 10**: Discuss what can we learn from the displayed scatterplot.

# %% [markdown]
# **Answer 10**
#
# There is an inverse relationship between MPG and Weight. The lighter the car, the higher the MPG is.

# %% [markdown]
# We can decide on the size and collor of circles to represent some of data properties. Here, the size is proportional to Cylinders and color is related to Horsepower:

# %%
plt.figure(figsize=(10,6))
plt.xlabel("MPG")
plt.ylabel("Weight")
plt.scatter(df['MPG'],df['Weight'],df['Cylinders']*50,df['Horsepower']);

# %% [markdown]
# **Question 11**: Discuss what additional insight we can get from this scatterplot as compared to the previous scatterplot. Plot another scatterplot by picking a different set of attributes that you think is providing a useful view at the data. Discuss what can be concluded from that plot.

# %% [markdown]
# **Answer:** For the new scatter plot, bigger cylinders correlate to heavier (bigger weight) cars.
#
# Higher horsepower correlates to higher MPG because the darker circles
# are more concentrated near the cars with higher MPG.

# %% [markdown]
# Pandas `scatter_matrix` method allows us to plot all scatterplots for a data set (it would take a few seconds to display):

# %%
pd.plotting.scatter_matrix(df, figsize=(15, 15));

# %% [markdown]
# **Question 12**: Explain what are we seeing from this plot and discuss about the insights you obtained from it.
#
# When you are done with running and playing with the code provided in this file and answering Questions 1-12, **submit** `.ipynb` file containing modifications of this file together with your answers and comments. Feel free to modify the provided code or produce new lines of code.
#
# **Answer 12**
#
# From the scatter matrix, we see that Pandas plot each column against
# itself and every other column. For a column that is not itself, Pandas
# create a scatterplot and if the column is itself, it defaults to a histogram
# plot.
#
# This plot contains a lot of information. It is best plot each column
# against one another individually to understand the correlation or trend
# better.
#
# There are some scatter plots with upward or downward trends, which make
# them more insightful than those with horizontal or vertical lines.
#
# **Question 13**: Produce a 2 page word document titled "Exploratory Analysis of MPG Data Set". In this document you should combine your own discussion and figures produced by Python to provide a coherent story about the properties of the MPG data set and the most important and interesting insights about the data. You can feel free to frame your story around some known historical facts about the cars and U.S. and World economy during the 1970-1982 period. **Submit** the document as `.pdf` file.

# %% [markdown]
# ### Below are just extra stuff for the word document

# %%
# new modification from original notebook
plt.figure(figsize=(5,3))

# first arg is x and second arg is y
plt.xlabel("MPG")
plt.ylabel("Horsepower")
plt.scatter(df['MPG'],df['Horsepower']);

# %% [markdown]
# From the scatterplot, I am interested in cars that have 200 or more Horsepower while having MPG of less than 20

# %%
df[df['MPG'] < 20][df['Horsepower'] > 200]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#                               Car   MPG  Cylinders  Displacement  Horsepower  \
# 6                Chevrolet Impala  14.0          8         454.0         220
# 7               Plymouth Fury iii  14.0          8         440.0         215
# 8                Pontiac Catalina  14.0          8         455.0         225
# 19        Buick Estate Wagon (sw)  14.0          8         455.0         225
# 31                      Ford F250  10.0          8         360.0         215
# 33                     Dodge D200  11.0          8         318.0         210
# 74                Mercury Marquis  11.0          8         429.0         208
# 101  Chrysler New Yorker Brougham  13.0          8         440.0         215
# 102      Buick Electra 225 Custom  12.0          8         455.0         225
# ...

# %% [markdown]
# We can see that those with more than 200 Horsepower while have MPG of less than 20 are made in 1970 to 1973 and in the US.

# %%
# new modification from original notebook
df.boxplot(column='Horsepower', by='Model');
